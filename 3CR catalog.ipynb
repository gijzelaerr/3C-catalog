# %%
file_ = 'original/3cr.dat'

# %%
def extract(line, start, stop):
    return line[start:stop].strip()


def dms2deg(hour, min_, sec):
    deg = abs(hour) * 15 # there are 15 degrees in one hour
    deg += min_ / 4 # there are 4 minutes in one degree
    deg += sec / 240 # there are 240 seconds in one degree
    
    if hour < 0:
        return deg*-1
    return deg

# %%
  
for line in open(file_, 'r').readlines():
    designation = float(extract(line, 0, 5))  #  3CR source designation (1)
    RAh = int(extract(line, 7, 9))            #  Right ascension in h (1950.0) 
    RAm = int(extract(line, 10, 12))          #  Right ascension in min (1950.0)
    RAs = float(extract(line, 13, 17))        #  Right ascension in s (1950.0)
    e_RAs = float(extract(line, 19, 23))      #  rms uncertainty on right ascension ins
    
    ra = dms2deg(RAh, RAm, RAs)
    
    
    decl = float(extract(line, 25, 27))        #  Declination (1950.0) in deg
    sign = extract(line, 24, 25)              #  Declination sign (1950.0)
    if sign == "-":
        decl = decl * -1

    DEm = float(extract(line, 28, 32))        #  Declination (1950.0) in arcmin 
    e_DEm = float(extract(line, 33, 39))      #  rms uncertainty on declination in arcmin
    GLON = float(extract(line, 40, 43))       #  Galactic longitude in deg
    GLAT = float(extract(line, 45, 48))       #  Galactic latitude in deg
    flux = float(extract(line, 49, 56))       #  Flux density at 178MHz in Jy
    flux_  = extract(line, 56, 57)            #  469{lambda} interferometer (2)
    l_Diam = extract(line, 60, 61)            #  Limit flag on Diam
    Diam = extract(line, 61, 65)              #  Angular diameter
    x_Diam = extract(line, 65, 66)            #  ["'] Units of diameter (' or ")
    e_Diam = extract(line, 66, 70)            #  rms uncertainty on Diam
    f_Diam =extract(line, 70, 71)             #  [)] Confusing sources
    notes = extract(line, 72, 208)            #  Notes
    
    print(ra, decl, flux)
# Out:
# (0.20416666666666666, -0.0, 15.0)
# (3.05, 79.0, 16.0)
# (4.208333333333333, 15.0, 15.0)
# (5.2004166666666665, 63.0, 134.0)
# (6.025, 63.0, 11.5)
# (7.145833333333333, 39.0, 10.5)
# (8.1275, 18.0, 9.5)
# (8.15, 59.0, 14.0)
# (8.1375, -1.0, 14.5)
# (8.025, 12.0, 11.5)
# (8.216666666666667, -2.0, 21.0)
# (9.058333333333334, 32.0, 9.0)
# (9.0625, 9.0, 23.0)
# (10.082916666666666, 51.0, 41.0)
# (10.125, 67.0, 9.0)
# (12.025833333333333, 50.0, 14.5)
# (13.175, 68.0, 24.0)
# (13.039166666666667, 26.0, 14.0)
# (13.0125, -1.0, 15.0)
# (16.175, 32.0, 15.5)
# (16.057083333333335, 13.0, 49.0)
# (16.1, 72.0, 12.0)
# (16.225, 69.0, 9.0)
# (16.135, 31.0, 11.0)
# (17.029583333333335, 49.0, 12.5)
# (18.058333333333334, 45.0, 9.5)
# (20.145833333333332, -1.0, 24.0)
# (20.230416666666667, 32.0, 10.0)
# (21.1825, 28.0, 11.5)
# (21.063333333333333, 23.0, 11.5)
# (22.19333333333333, 6.0, 11.0)
# (23.158333333333335, 37.0, 9.5)
# (23.170416666666668, 20.0, 20.0)
# (23.204583333333332, 32.0, 47.0)
# (24.133333333333333, 13.0, 11.5)
# (26.07625, 53.0, 10.0)
# (28.11541666666667, 43.0, 10.0)
# (28.085, 28.0, 21.0)
# (30.170833333333334, 64.0, 24.0)
# (33.0, 85.0, 29.0)
# (34.085, -2.0, 15.0)
# (35.04333333333334, 42.0, 33.0)
# (35.157916666666665, 39.0, 27.0)
# (35.07625, 27.0, 10.0)
# (37.12083333333333, 34.0, 17.0)
# (37.100833333333334, 31.0, 12.0)
# (38.083333333333336, 58.0, 23.0)
# (40.025, -0.0, 13.5)
# (43.01166666666666, 5.0, 23.0)
# (45.11666666666667, 16.0, 9.5)
# (46.205416666666665, 3.0, 15.0)
# (46.04333333333334, 16.0, 24.0)
# (48.23041666666666, 41.0, 28.0)
# (49.12083333333333, 41.0, 58.0)
# (50.13, 55.0, 21.0)
# (51.07875, 2.0, 16.0)
# (52.19166666666667, -1.0, 18.5)
# (53.01708333333333, 50.0, 12.5)
# (55.22, 4.0, 9.5)
# (56.15, 33.0, 10.0)
# (59.04375, 10.0, 41.0)
# (59.125, 0.0, 10.0)
# (61.145833333333336, 42.0, 25.0)
# (61.19625, 3.0, 15.0)
# (62.229166666666664, -1.0, 11.0)
# (62.229166666666664, 11.0, 19.5)
# (63.00666666666667, 37.0, 57.0)
# (64.12291666666667, 17.0, 10.0)
# (67.03541666666666, 41.0, 15.0)
# (68.2325, 29.0, 175.0)
# (69.1, 1.0, 9.5)
# (70.20833333333333, 39.0, 9.5)
# (71.10291666666667, 44.0, 21.0)
# (71.175, 44.0, 10.5)
# (72.20833333333333, 51.0, 12.5)
# (72.04083333333334, 31.0, 13.5)
# (73.17791666666666, 22.0, 12.5)
# (74.22708333333334, 25.0, 19.5)
# (75.07375, 38.0, 66.0)
# (77.17916666666666, 1.0, 16.0)
# (78.225, 24.0, 13.0)
# (78.15875, 50.0, 9.0)
# (79.06666666666666, 16.0, 18.5)
# (79.0875, 34.0, 20.0)
# (80.07958333333333, 28.0, 11.0)
# (80.10958333333333, 32.0, 13.0)
# (82.20375, 6.0, 18.0)
# (82.125, 21.0, 1420.0)
# (84.18458333333334, 49.0, 58.0)
# (84.0125, -1.0, 14.5)
# (90.12875, 20.0, 11.0)
# (91.18583333333333, 48.0, 17.5)
# (91.175, 21.0, 19.0)
# (92.18125, 26.0, 19.0)
# (93.15, 22.0, 210.0)
# (94.20833333333333, 14.0, 14.0)
# (100.01833333333333, 23.0, 11.0)
# (100.10666666666667, 21.0, 13.0)
# (101.175, 45.0, 9.5)
# (102.06166666666667, 54.0, 23.0)
# (104.2375, 38.0, 10.0)
# (104.01958333333333, 25.0, 14.0)
# (105.0, 75.0, 12.0)
# (107.06416666666667, 11.0, 16.0)
# (107.1125, 15.0, 11.5)
# (110.1875, 15.0, 9.5)
# (111.14166666666667, -1.0, 14.0)
# (111.08333333333333, 14.0, 13.0)
# (113.14166666666667, 70.0, 11.0)
# (113.225, 80.0, 12.0)
# (115.01666666666667, 38.0, 13.5)
# (115.10833333333333, 1.0, 11.0)
# (119.21666666666667, 14.0, 11.0)
# (120.01833333333333, 10.0, 10.5)
# (120.15166666666667, 24.0, 19.5)
# (121.16208333333333, 42.0, 9.0)
# (122.00458333333333, 48.0, 59.0)
# (123.0875, -2.0, 14.5)
# (124.0875, 46.0, 9.5)
# (124.21625, 6.0, 16.5)
# (126.08333333333333, 29.0, 13.0)
# (128.24583333333334, 65.0, 9.5)
# (128.11666666666667, 57.0, 12.5)
# (129.05, 12.0, 10.0)
# (132.09791666666666, 14.0, 16.0)
# (133.0, 14.0, 12.5)
# (133.05416666666667, 28.0, 10.5)
# (134.0, 14.0, 15.5)
# (134.03, 29.0, 11.0)
# (135.185, 16.0, 10.0)
# (136.22916666666666, 38.0, 12.0)
# (136.08125, 43.0, 18.5)
# (139.21458333333334, 45.0, 44.0)
# (141.175, 80.0, 12.0)
# (141.2125, 36.0, 9.5)
# (143.0, 83.0, 14.5)
# (143.22833333333332, 4.0, 9.0)
# (144.22083333333333, 36.0, 14.5)
# (144.08333333333334, 39.0, 9.5)
# (144.15, 14.0, 25.0)
# (145.17083333333332, 10.0, 13.5)
# (146.02916666666667, 7.0, 28.0)
# (146.10416666666666, 14.0, 16.0)
# (147.10666666666665, 0.0, 21.0)
# (147.08333333333334, 70.0, 13.0)
# (149.23875, 29.0, 29.0)
# (150.025, 35.0, 9.0)
# (151.0925, 7.0, 24.0)
# (152.09583333333333, 6.0, 13.0)
# (152.2, 46.0, 12.0)
# (154.04125, 22.0, 10.0)
# (157.125, 58.0, 19.0)
# (160.0625, 12.0, 9.5)
# (164.03916666666666, 43.0, 15.5)
# (164.15416666666667, -1.0, 20.0)
# (165.05, 77.0, 11.5)
# (166.04875, 25.0, 11.0)
# (167.24166666666667, 35.0, 12.0)
# (167.22625, 40.0, 19.0)
# (169.00833333333333, -2.0, 16.5)
# (169.01916666666668, 23.0, 9.5)
# (170.17916666666667, 5.0, 9.0)
# (170.05, 19.0, 9.0)
# (174.22916666666666, 66.0, 13.0)
# (175.20708333333334, 22.0, 17.5)
# (175.13208333333333, 19.0, 24.0)
# (175.21833333333333, 31.0, 18.0)
# (175.02458333333334, 50.0, 9.0)
# (176.10833333333332, 13.0, 13.5)
# (179.225, 73.0, 19.5)
# (179.105, 31.0, 9.0)
# (181.05, 64.0, 9.5)
# (181.18583333333333, 43.0, 9.0)
# (184.15958333333333, 6.0, 44.0)
# (184.01958333333334, 33.0, 12.0)
# (185.01083333333332, 42.0, 9.5)
# (185.14583333333334, 13.0, 18.0)
# (186.1325, 2.0, 67.0)
# (187.075, 12.0, 970.0)
# (188.23833333333334, 21.0, 15.0)
# (189.20416666666668, -4.0, 9.5)
# (190.11625, 16.0, 16.0)
# (192.11875, 50.0, 12.5)
# (192.075, 57.0, 12.0)
# (192.0125, 15.0, 9.5)
# (192.19875, 27.0, 11.5)
# (193.17833333333334, 47.0, 20.0)
# (194.05916666666667, 40.0, 11.0)
# (197.18041666666667, 27.0, 10.5)
# (199.03208333333333, 42.0, 10.5)
# (202.07083333333333, 25.0, 14.0)
# (202.20833333333334, 30.0, 21.0)
# (202.0875, 2.0, 11.5)
# (204.15833333333333, 39.0, 14.5)
# (205.2, 60.0, 9.5)
# (205.12166666666667, 50.0, 9.5)
# (207.0125, 31.0, 12.0)
# (208.0875, 16.0, 9.5)
# (211.14583333333334, 34.0, 9.0)
# (212.14083333333335, 52.0, 73.0)
# (213.09583333333333, 8.0, 12.5)
# (213.1875, -3.0, 9.5)
# (214.16208333333333, 6.0, 44.0)
# (214.03125, 41.0, 11.0)
# (215.1675, 19.0, 16.0)
# (216.025, -1.0, 10.5)
# (220.10166666666666, 52.0, 12.5)
# (221.025, 77.0, 11.5)
# (222.0375, 63.0, 13.5)
# (222.1, 76.0, 11.5)
# (223.1875, -3.0, 12.5)
# (224.175, 72.0, 17.0)
# (225.20708333333334, 26.0, 51.0)
# (227.13583333333332, 8.0, 28.0)
# (227.2, 71.0, 9.0)
# (227.13, 26.0, 17.5)
# (228.07375, 7.0, 43.0)
# (229.21416666666667, 20.0, 10.0)
# (229.09916666666666, 7.0, 11.0)
# (230.2, 54.0, 17.0)
# (232.15416666666667, 35.0, 11.5)
# (232.16833333333332, 24.0, 12.5)
# (233.03333333333333, 56.0, 9.5)
# (235.2375, 60.0, 9.5)
# (236.13583333333332, 21.0, 9.0)
# (236.1625, 21.0, 11.5)
# (237.03333333333333, 62.0, 10.5)
# (237.0575, 20.0, 10.0)
# (238.24166666666667, 20.0, 9.0)
# (239.24583333333334, 2.0, 40.0)
# (240.0575, 1.0, 24.0)
# (242.24583333333334, 66.0, 24.0)
# (243.19458333333333, 32.0, 10.5)
# (244.02833333333334, 17.0, 10.0)
# (245.13666666666666, 23.0, 13.5)
# (246.01958333333334, 27.0, 10.5)
# (246.23625, 39.0, 41.0)
# (246.06666666666666, 44.0, 17.0)
# (246.12541666666667, 23.0, 11.0)
# (248.075, 62.0, 9.5)
# (249.025, 62.0, 9.0)
# (250.0775, 39.0, 10.0)
# (250.14458333333334, 17.0, 11.0)
# (252.16791666666666, 5.0, 325.0)
# (254.04166666666666, 47.0, 12.0)
# (256.0125, 60.0, 11.0)
# (257.0625, 46.0, 11.0)
# (259.23375, -0.0, 203.0)
# (260.025, 51.0, 14.5)
# (261.11083333333335, 31.0, 9.0)
# (267.125, 5.0, 90.0)
# (270.175, 10.0, 14.0)
# (271.01666666666665, 69.0, 9.5)
# (273.175, -3.0, 41.0)
# (276.1, 74.0, 9.5)
# (277.06083333333333, 48.0, 57.0)
# (278.1166666666667, 47.0, 12.5)
# (278.05, 32.0, 20.0)
# (279.0495833333333, 17.0, 24.0)
# (280.15416666666664, 45.0, 22.0)
# (280.05, 9.0, 19.0)
# (280.17083333333335, -3.0, 21.0)
# (281.0, 6.0, 51.0)
# (281.05, -3.0, 110.0)
# (281.05, 80.0, 44.0)
# (281.1958333333333, -0.0, 24.0)
# (283.14166666666665, 1.0, 400.0)
# (284.0083333333333, 12.0, 12.0)
# (285.14875, 5.0, 22.0)
# (286.125, -3.0, 30.0)
# (286.03041666666667, 7.0, 28.0)
# (287.18333333333334, 9.0, 55.0)
# (288.2475, 30.0, 12.5)
# (288.175, 10.0, 19.0)
# (290.125, 14.0, 540.0)
# (290.2, 35.0, 16.5)
# (294.125, 17.0, 22.0)
# (294.15416666666664, 60.0, 19.0)
# (295.11125, 50.0, 13.0)
# (297.1816666666667, 2.0, 26.0)
# (297.225, -2.0, 12.5)
# (298.0, 31.0, 50.0)
# (299.18875, 40.0, 8100.0)
# (303.07708333333335, 23.0, 73.0)
# (304.0, 45.0, 230.0)
# (304.01125, 29.0, 32.0)
# (304.15, 40.0, 410.0)
# (304.1958333333333, 9.0, 14.0)
# (307.025, 43.0, 24.0)
# (307.08666666666664, 53.0, 10.0)
# (308.1, 46.0, 60.0)
# (308.0, 41.0, 160.0)
# (309.02958333333333, 51.0, 12.5)
# (309.025, 42.0, 74.0)
# (311.185, 6.0, 12.5)
# (316.05, 76.0, 23.0)
# (316.18833333333333, 49.0, 19.0)
# (319.2375, 60.0, 29.0)
# (319.0520833333333, 49.0, 21.0)
# (320.1091666666667, 16.0, 11.5)
# (320.13375, 24.0, 52.0)
# (320.1875, 15.0, 10.5)
# (320.025, 51.0, 23.0)
# (321.1625, 7.0, 9.5)
# (323.05, 84.0, 12.0)
# (325.24625, 27.0, 15.0)
# (326.0, 15.0, 10.5)
# (327.1, 13.0, 5.0)
# (328.18958333333336, 37.0, 37.0)
# (330.20875, 29.0, 13.0)
# (333.23333333333335, 13.0, 20.0)
# (335.0545833333333, -2.0, 23.0)
# (337.0375, 38.0, 13.5)
# (340.13958333333335, 39.0, 49.0)
# (342.04, 18.0, 9.0)
# (342.15, 71.0, 9.5)
# (342.1, 64.0, 10.5)
# (342.175, 15.0, 15.0)
# (343.175, 13.0, 13.0)
# (347.01666666666665, 9.0, 13.0)
# (347.08458333333334, 5.0, 10.0)
# (348.01166666666666, 3.0, 22.0)
# (349.00125, 23.0, 9.5)
# (350.0441666666667, 58.0, 11000.0)
# (354.00416666666666, 26.0, 35.0)
# (357.15, 64.0, 34.0)
# (358.125, 79.0, 11.5)
# (359.01708333333335, 43.0, 9.0)
